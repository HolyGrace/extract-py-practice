# %%
import pandas as pd

# %%
# This will read the tables found on the web page.
aoe_tables = pd.read_html("https://es.wikipedia.org/wiki/Age_of_Empires_(serie)")

# %%
len(aoe_tables)
# Out:
# 4

# %%
aoe_tables[2]
# Out:
#                                  Juegos y expansiones GameRankings Metacritic
# 0                               Age of Empires (1997)     87%[80]​   83%[13]​
# 1           - Age of Empires: The Rise of Rome (1998)     80%[16]​          -
# 2           Age of Empires: Definitive Edition (2018)            -   69%[19]​
# 3          Age of Empires II: The Age of Kings (1999)     92%[18]​   92%[19]​
# 4          - Age of Empires II: The Conquerors (2000)     88%[81]​   88%[82]​
# 5                Age of Empires II: HD Edition (2013)     71%[83]​   68%[84]​
# 6           - Age of Empires II: The Forgotten (2013)            -          -
# 7    - Age of Empires II: The African Kingdoms (2015)            -          -
# 8       - Age of Empires II: Rise of the Rajas (2016)            -          -
# 9   Age of Empires II: Definitive Edition (incluid...            -   84%[19]​
# 10  - Age of Empires II: Definitive Edition - Lord...            -          -
# ...
